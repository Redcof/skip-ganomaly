# %%
from options import Options
from lib.data.dataloader import load_data
from lib.models import load_model
import cv2
import warnings
warnings.filterwarnings('ignore')

import matplotlib.pyplot as plt
# disable latex error
# plt.rcParams.update({
#     "text.usetex": False,
# })
# !pwd
# Out:
# /mnt/c/Users/dndlssardar/OneDrive - Smiths Group/Documents/Soumen/skip-ganomaly/lib/data/sixray_sd3_anomaly_dataset.py:74: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if nc is 3:
# /mnt/c/Users/dndlssardar/OneDrive - Smiths Group/Documents/Soumen/skip-ganomaly

# %%
algorithm_name = 'ganomaly'
experiment_name = 'sixray_sd3' 
data_path = 'dataset/sample'
dataset_name = 'sixray_sd3'
phase = 'test'
device = 'cpu'
imsize = 128
checkpoint = 'output/ganomaly/sixray_sd3/train/weights/final'
nc = 1
class Option:
    def __init__(self):
        self.dataset=dataset_name
        self.dataroot=data_path      
        self.patht=''
        self.batchsize=1
        self.workers=8
        self.droplast=False
        self.isize=imsize
        self.nc=nc
        self.nz=100
        self.ngf=64
        self.ndf=64
        self.extralayers=0
        self.device=device
        self.gpu_ids=[0]
        self.ngpu=1
        self.name= experiment_name
        self.model = algorithm_name
        self.display_server="http://localhost"
        self.display_port=8097
        self.display_id=0,
        self.display=False
        self.verbose= False
        self.outf='./output'
        self.manualseed=47
        self.abnormal_class=''
        self.metric='roc'

        ##
        # Train
        self.print_freq=100
        self.save_image_freq=100
        self.save_test_images=False
        self.load_weights=False
        self.resume = checkpoint
        self.phase=phase
        self.iter=0
        self.niter=15
        self.niter_decay=100
        self.beta1=0.5
        self.lr=0.0002
        self.w_adv=1
        self.w_con=50
        self.w_lat=1
        self.lr_policy='lambda'
        self.lr_decay_iters=50

        self.isTrain = False

opt = Option()

# %%
input = 127.0
mean = 0.5
std = 0.06
# normalize
norm = (input - mean) / std
# inverse normalize
orig = (norm * std) + mean
norm, round(orig, 5)==round(input, 5), orig, input
# Out:
# (2108.3333333333335, True, 127.0, 127.0)

# %%
def tensor_to_cv(tensor_img):
    np_img = np.moveaxis(tensor_img.numpy(), 0, -1)
    return np_img

def inverse_normalize_tensor(tensor_img, mean, std):
    """
    This is an in-place inverse-normalization algorithm
    Inverse-Normalized = (input * std) + mean
    """
    np_img = tensor_to_cv(tensor_img)
    # print("shapes", tensor_img.shape, np_img.shape)
    func = lambda i, m, s: (i * s) + m
    for ch in range(np_img.ndim):
        np_img[:,:,ch] = func(np_img[:,:,ch], mean[ch], std[ch])
    return np_img

# %%
"dataset/sample/train/0.normal/P00080.jpg"
img = cv2.imread("dataset/sample/test/1.abnormal/P00549.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()

# %%
from PIL import Image
from lib.data.sixray_sd3_anomaly_dataset import get_transforms
from torchvision import transforms
import numpy as np
# conver cv to PIL
pil_im = Image.fromarray(img)
# transform
X = get_transforms((imsize, imsize), nc)(pil_im)
print("Input shape:", X.shape)
# inverse transform
np_img = inverse_normalize_tensor(X, (0.5,0.5,0.5),(0.5,0.5,0.5))
# show image
plt.subplot(1,2,1)
plt.imshow(np_img)

plt.subplot(1,2,2)
plt.imshow(tensor_to_cv(X))
plt.show()
# Out:
# Input shape: torch.Size([1, 128, 128])
# tensor torch.Size([1, 128, 128])
# ndim 3
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[19], line 11
#       9 print("Input shape:", X.shape)
#      10 # inverse transform
# ---> 11 np_img = inverse_normalize_tensor(X, (0.5,0.5,0.5),(0.5,0.5,0.5))
#      12 # show image
#      13 plt.subplot(1,2,1)
#
# Cell In[17], line 18, in inverse_normalize_tensor(tensor_img, mean, std)
#      16 if np_img.ndim > 1:
#      17     for ch in range(np_img.ndim):
# ---> 18         np_img[:,:,ch] = func(np_img[:,:,ch], mean[ch], std[ch])
#      19     else:
#      20         np_img[:,:] = func(np_img[:,:,ch], mean[ch], std[ch])
#
# IndexError: index 1 is out of bounds for axis 2 with size 1

# %%
# load data
data = load_data(opt)
len(data.train)
# Out:
# 14

# %%
# load pretrained model
model = load_model(opt, None)
# Out:
# Loading pre-trained networks.
# 	Done.

# %%
# forward pass thru generator
fakeX_batch= model.netg(X.reshape(1, 3, imsize, imsize))[0].data
# inverse-normalize the generated image to RGB domain
np_img_fake = inverse_normalize_tensor(fakeX_batch[0], (0.5,0.5,0.5),(0.5,0.5,0.5))

plt.subplot(1, 2, 1)
plt.imshow(tensor_to_cv(X))

plt.subplot(1, 2, 2)
plt.imshow(np_img_fake)
plt.show()
# Out:
# shapes torch.Size([3, 128, 128]) (128, 128, 3)
